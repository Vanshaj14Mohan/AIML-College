# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import date

# %%
df = pd.read_csv(r"E:\AIML College\Files\used_car_dataset.csv")
df.head()
# Out:
#    Unnamed: 0                              Name    Location  Year  \
# 0           0            Maruti Wagon R LXI CNG      Mumbai  2010
# 1           1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2           2                      Honda Jazz V     Chennai  2011
# 3           3                 Maruti Ertiga VDI     Chennai  2012
# 4           4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
#
#    Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage   Engine  \
# 0              72000       CNG       Manual      First  26.6 km/kg   998 CC
# 1              41000    Diesel       Manual      First  19.67 kmpl  1582 CC
# 2              46000    Petrol       Manual      First   18.2 kmpl  1199 CC
# 3              87000    Diesel       Manual      First  20.77 kmpl  1248 CC
# 4              40670    Diesel    Automatic     Second   15.2 kmpl  1968 CC
#
#        Power  Seats  New_Price  Price
# 0  58.16 bhp    5.0        NaN   1.75
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6019 entries, 0 to 6018
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         6019 non-null   int64
#  1   Name               6019 non-null   object
#  2   Location           6019 non-null   object
#  3   Year               6019 non-null   int64
#  4   Kilometers_Driven  6019 non-null   int64
#  5   Fuel_Type          6019 non-null   object
#  6   Transmission       6019 non-null   object
#  7   Owner_Type         6019 non-null   object
#  8   Mileage            6017 non-null   object
#  9   Engine             5983 non-null   object
#  10  Power              5983 non-null   object
#  11  Seats              5977 non-null   float64
#  12  New_Price          824 non-null    object
#  13  Price              6019 non-null   float64
# dtypes: float64(2), int64(3), object(9)
# memory usage: 658.5+ KB

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Name', 'Location', 'Year', 'Kilometers_Driven',
#        'Fuel_Type', 'Transmission', 'Owner_Type', 'Mileage', 'Engine', 'Power',
#        'Seats', 'New_Price', 'Price'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Unnamed: 0             int64
# Name                  object
# Location              object
# Year                   int64
# Kilometers_Driven      int64
# Fuel_Type             object
# Transmission          object
# Owner_Type            object
# Mileage               object
# Engine                object
# Power                 object
# Seats                float64
# New_Price             object
# Price                float64
# dtype: object

# %%
df.shape
# Out:
# (6019, 14)

# %%
df.tail()
# Out:
#       Unnamed: 0                      Name   Location  Year  \
# 6014        6014          Maruti Swift VDI      Delhi  2014
# 6015        6015  Hyundai Xcent 1.1 CRDi S     Jaipur  2015
# 6016        6016     Mahindra Xylo D4 BSIV     Jaipur  2012
# 6017        6017        Maruti Wagon R VXI    Kolkata  2013
# 6018        6018     Chevrolet Beat Diesel  Hyderabad  2011
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage  \
# 6014              27365    Diesel       Manual      First   28.4 kmpl
# 6015             100000    Diesel       Manual      First   24.4 kmpl
# 6016              55000    Diesel       Manual     Second   14.0 kmpl
# 6017              46000    Petrol       Manual      First   18.9 kmpl
# 6018              47000    Diesel       Manual      First  25.44 kmpl
#
#        Engine     Power  Seats  New_Price  Price
# 6014  1248 CC    74 bhp    5.0  7.88 Lakh   4.75
# 6015  1120 CC    71 bhp    5.0        NaN   4.00
# ...

# %%
df.sample()
# Out:
#      Unnamed: 0              Name Location  Year  Kilometers_Driven Fuel_Type  \
# 939         939  Jaguar XF Diesel  Kolkata  2012              43510    Diesel
#
#     Transmission Owner_Type     Mileage   Engine      Power  Seats New_Price  \
# 939    Automatic      First  14.74 kmpl  2993 CC  270.9 bhp    5.0       NaN
#
#      Price
# 939   20.5

# %%
df.drop(["Unnamed: 0"], axis = 1, inplace=True)
df.head()
# Out:
#                                Name    Location  Year  Kilometers_Driven  \
# 0            Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                      Honda Jazz V     Chennai  2011              46000
# 3                 Maruti Ertiga VDI     Chennai  2012              87000
# 4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
#
#   Fuel_Type Transmission Owner_Type     Mileage   Engine      Power  Seats  \
# 0       CNG       Manual      First  26.6 km/kg   998 CC  58.16 bhp    5.0
# 1    Diesel       Manual      First  19.67 kmpl  1582 CC  126.2 bhp    5.0
# 2    Petrol       Manual      First   18.2 kmpl  1199 CC   88.7 bhp    5.0
# 3    Diesel       Manual      First  20.77 kmpl  1248 CC  88.76 bhp    7.0
# 4    Diesel    Automatic     Second   15.2 kmpl  1968 CC  140.8 bhp    5.0
#
#    New_Price  Price
# 0        NaN   1.75
# 1        NaN  12.50
# ...

# %%
df.head()
# Out:
#                                Name    Location  Year  Kilometers_Driven  \
# 0            Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                      Honda Jazz V     Chennai  2011              46000
# 3                 Maruti Ertiga VDI     Chennai  2012              87000
# 4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
#
#   Fuel_Type Transmission Owner_Type     Mileage   Engine      Power  Seats  \
# 0       CNG       Manual      First  26.6 km/kg   998 CC  58.16 bhp    5.0
# 1    Diesel       Manual      First  19.67 kmpl  1582 CC  126.2 bhp    5.0
# 2    Petrol       Manual      First   18.2 kmpl  1199 CC   88.7 bhp    5.0
# 3    Diesel       Manual      First  20.77 kmpl  1248 CC  88.76 bhp    7.0
# 4    Diesel    Automatic     Second   15.2 kmpl  1968 CC  140.8 bhp    5.0
#
#    New_Price  Price
# 0        NaN   1.75
# 1        NaN  12.50
# ...

# %%
df.drop(["Location"], axis =1, inplace=True)
df.head()
# Out:
#                                Name  Year  Kilometers_Driven Fuel_Type  \
# 0            Maruti Wagon R LXI CNG  2010              72000       CNG
# 1  Hyundai Creta 1.6 CRDi SX Option  2015              41000    Diesel
# 2                      Honda Jazz V  2011              46000    Petrol
# 3                 Maruti Ertiga VDI  2012              87000    Diesel
# 4   Audi A4 New 2.0 TDI Multitronic  2013              40670    Diesel
#
#   Transmission Owner_Type     Mileage   Engine      Power  Seats  New_Price  \
# 0       Manual      First  26.6 km/kg   998 CC  58.16 bhp    5.0        NaN
# 1       Manual      First  19.67 kmpl  1582 CC  126.2 bhp    5.0        NaN
# 2       Manual      First   18.2 kmpl  1199 CC   88.7 bhp    5.0  8.61 Lakh
# 3       Manual      First  20.77 kmpl  1248 CC  88.76 bhp    7.0        NaN
# 4    Automatic     Second   15.2 kmpl  1968 CC  140.8 bhp    5.0        NaN
#
#    Price
# 0   1.75
# 1  12.50
# 2   4.50
# 3   6.00
# 4  17.74

# %%
df.drop([2], axis=0, inplace=True)
df.head()
# Out:
#                                Name  Year  Kilometers_Driven Fuel_Type  \
# 0            Maruti Wagon R LXI CNG  2010              72000       CNG
# 1  Hyundai Creta 1.6 CRDi SX Option  2015              41000    Diesel
# 3                 Maruti Ertiga VDI  2012              87000    Diesel
# 4   Audi A4 New 2.0 TDI Multitronic  2013              40670    Diesel
# 5   Hyundai EON LPG Era Plus Option  2012              75000       LPG
#
#   Transmission Owner_Type     Mileage   Engine      Power  Seats New_Price  \
# 0       Manual      First  26.6 km/kg   998 CC  58.16 bhp    5.0       NaN
# 1       Manual      First  19.67 kmpl  1582 CC  126.2 bhp    5.0       NaN
# 3       Manual      First  20.77 kmpl  1248 CC  88.76 bhp    7.0       NaN
# 4    Automatic     Second   15.2 kmpl  1968 CC  140.8 bhp    5.0       NaN
# 5       Manual      First  21.1 km/kg   814 CC   55.2 bhp    5.0       NaN
#
#    Price
# 0   1.75
# 1  12.50
# 3   6.00
# 4  17.74
# 5   2.35

# %%
# df.drop([3], axis=0, inplace=True)
df.drop([3,5],axis =0, inplace=True)
df.head()
# Out:
#                                 Name  Year  Kilometers_Driven Fuel_Type  \
# 0             Maruti Wagon R LXI CNG  2010              72000       CNG
# 1   Hyundai Creta 1.6 CRDi SX Option  2015              41000    Diesel
# 4    Audi A4 New 2.0 TDI Multitronic  2013              40670    Diesel
# 6             Nissan Micra Diesel XV  2013              86999    Diesel
# 7  Toyota Innova Crysta 2.8 GX AT 8S  2016              36000    Diesel
#
#   Transmission Owner_Type     Mileage   Engine      Power  Seats New_Price  \
# 0       Manual      First  26.6 km/kg   998 CC  58.16 bhp    5.0       NaN
# 1       Manual      First  19.67 kmpl  1582 CC  126.2 bhp    5.0       NaN
# 4    Automatic     Second   15.2 kmpl  1968 CC  140.8 bhp    5.0       NaN
# 6       Manual      First  23.08 kmpl  1461 CC   63.1 bhp    5.0       NaN
# 7    Automatic      First  11.36 kmpl  2755 CC  171.5 bhp    8.0   21 Lakh
#
#    Price
# 0   1.75
# 1  12.50
# 4  17.74
# 6   3.50
# 7  17.50

# %%
df1=df.drop([6],axis =0, inplace=False)
df1.head()
# Out:
#                                   Name  Year  Kilometers_Driven Fuel_Type  \
# 0               Maruti Wagon R LXI CNG  2010              72000       CNG
# 1     Hyundai Creta 1.6 CRDi SX Option  2015              41000    Diesel
# 4      Audi A4 New 2.0 TDI Multitronic  2013              40670    Diesel
# 7    Toyota Innova Crysta 2.8 GX AT 8S  2016              36000    Diesel
# 8  Volkswagen Vento Diesel Comfortline  2013              64430    Diesel
#
#   Transmission Owner_Type     Mileage   Engine      Power  Seats New_Price  \
# 0       Manual      First  26.6 km/kg   998 CC  58.16 bhp    5.0       NaN
# 1       Manual      First  19.67 kmpl  1582 CC  126.2 bhp    5.0       NaN
# 4    Automatic     Second   15.2 kmpl  1968 CC  140.8 bhp    5.0       NaN
# 7    Automatic      First  11.36 kmpl  2755 CC  171.5 bhp    8.0   21 Lakh
# 8       Manual      First  20.54 kmpl  1598 CC  103.6 bhp    5.0       NaN
#
#    Price
# 0   1.75
# 1  12.50
# 4  17.74
# 7  17.50
# 8   5.20

# %%
df.drop([1], axis=0, inplace=False)
df.head()
# Out:
#                                 Name  Year  Kilometers_Driven Fuel_Type  \
# 0             Maruti Wagon R LXI CNG  2010              72000       CNG
# 1   Hyundai Creta 1.6 CRDi SX Option  2015              41000    Diesel
# 4    Audi A4 New 2.0 TDI Multitronic  2013              40670    Diesel
# 6             Nissan Micra Diesel XV  2013              86999    Diesel
# 7  Toyota Innova Crysta 2.8 GX AT 8S  2016              36000    Diesel
#
#   Transmission Owner_Type     Mileage   Engine      Power  Seats New_Price  \
# 0       Manual      First  26.6 km/kg   998 CC  58.16 bhp    5.0       NaN
# 1       Manual      First  19.67 kmpl  1582 CC  126.2 bhp    5.0       NaN
# 4    Automatic     Second   15.2 kmpl  1968 CC  140.8 bhp    5.0       NaN
# 6       Manual      First  23.08 kmpl  1461 CC   63.1 bhp    5.0       NaN
# 7    Automatic      First  11.36 kmpl  2755 CC  171.5 bhp    8.0   21 Lakh
#
#    Price
# 0   1.75
# 1  12.50
# 4  17.74
# 6   3.50
# 7  17.50

# %%
df.nunique()
# Out:
# Name                 1875
# Year                   22
# Kilometers_Driven    3093
# Fuel_Type               5
# Transmission            2
# Owner_Type              4
# Mileage               441
# Engine                146
# Power                 372
# Seats                   9
# New_Price             539
# Price                1373
# dtype: int64

# %%
df.isnull().sum().plot(kind="bar", figsize=(10,1))
# Out:
# <Axes: >

# %%
df["Seats"].value_counts()
# Out:
# Seats
# 5.0     5012
# 7.0      673
# 8.0      134
# 4.0       99
# 6.0       31
# 2.0       16
# 10.0       5
# 9.0        3
# 0.0        1
# Name: count, dtype: int64

# %%
df["Seats"].value_counts().sum()
# Out:
# 5974

# %%
df["Fuel_Type"].value_counts().sum()
# Out:
# 6016

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6016 entries, 0 to 6018
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               6016 non-null   object
#  1   Year               6016 non-null   int64
#  2   Kilometers_Driven  6016 non-null   int64
#  3   Fuel_Type          6016 non-null   object
#  4   Transmission       6016 non-null   object
#  5   Owner_Type         6016 non-null   object
#  6   Mileage            6014 non-null   object
#  7   Engine             5980 non-null   object
#  8   Power              5980 non-null   object
#  9   Seats              5974 non-null   float64
#  10  New_Price          823 non-null    object
#  11  Price              6016 non-null   float64
# dtypes: float64(2), int64(2), object(8)
# memory usage: 740.0+ KB

# %%
df["Engine"].isnull().sum()
# Out:
# 36

# %%
df["Engine"].mode()
# Out:
# 0    1197 CC
# Name: Engine, dtype: object

# %%
df["Seats"].isnull().sum()
# Out:
# 42

# %%
df["Seats"].mode()
# Out:
# 0    5.0
# Name: Seats, dtype: float64

# %%
df["Engine"] = df["Engine"].fillna(df["Engine"].mode()[0]) # Replace missing values with the most frequent value
df.head()
# Out:
#                                 Name  Year  Kilometers_Driven Fuel_Type  \
# 0             Maruti Wagon R LXI CNG  2010              72000       CNG
# 1   Hyundai Creta 1.6 CRDi SX Option  2015              41000    Diesel
# 4    Audi A4 New 2.0 TDI Multitronic  2013              40670    Diesel
# 6             Nissan Micra Diesel XV  2013              86999    Diesel
# 7  Toyota Innova Crysta 2.8 GX AT 8S  2016              36000    Diesel
#
#   Transmission Owner_Type     Mileage   Engine      Power  Seats New_Price  \
# 0       Manual      First  26.6 km/kg   998 CC  58.16 bhp    5.0       NaN
# 1       Manual      First  19.67 kmpl  1582 CC  126.2 bhp    5.0       NaN
# 4    Automatic     Second   15.2 kmpl  1968 CC  140.8 bhp    5.0       NaN
# 6       Manual      First  23.08 kmpl  1461 CC   63.1 bhp    5.0       NaN
# 7    Automatic      First  11.36 kmpl  2755 CC  171.5 bhp    8.0   21 Lakh
#
#    Price
# 0   1.75
# 1  12.50
# 4  17.74
# 6   3.50
# 7  17.50

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6016 entries, 0 to 6018
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               6016 non-null   object
#  1   Year               6016 non-null   int64
#  2   Kilometers_Driven  6016 non-null   int64
#  3   Fuel_Type          6016 non-null   object
#  4   Transmission       6016 non-null   object
#  5   Owner_Type         6016 non-null   object
#  6   Mileage            6014 non-null   object
#  7   Engine             6016 non-null   object
#  8   Power              5980 non-null   object
#  9   Seats              5974 non-null   float64
#  10  New_Price          823 non-null    object
#  11  Price              6016 non-null   float64
# dtypes: float64(2), int64(2), object(8)
# memory usage: 740.0+ KB

# %%
df["New_Price"].isnull().sum()
# Out:
# 5193

# %%
df["New_Price"].mode()
# Out:
# 0     4.78 Lakh
# 1    63.71 Lakh
# 2    95.13 Lakh
# Name: New_Price, dtype: object

# %%
#For New Price
df["New_Price"] = df["New_Price"].fillna(df["New_Price"].mode()[0]) # Replace missing values with the most frequent value
df.head()
# Out:
#                                 Name  Year  Kilometers_Driven Fuel_Type  \
# 0             Maruti Wagon R LXI CNG  2010              72000       CNG
# 1   Hyundai Creta 1.6 CRDi SX Option  2015              41000    Diesel
# 4    Audi A4 New 2.0 TDI Multitronic  2013              40670    Diesel
# 6             Nissan Micra Diesel XV  2013              86999    Diesel
# 7  Toyota Innova Crysta 2.8 GX AT 8S  2016              36000    Diesel
#
#   Transmission Owner_Type     Mileage   Engine      Power  Seats  New_Price  \
# 0       Manual      First  26.6 km/kg   998 CC  58.16 bhp    5.0  4.78 Lakh
# 1       Manual      First  19.67 kmpl  1582 CC  126.2 bhp    5.0  4.78 Lakh
# 4    Automatic     Second   15.2 kmpl  1968 CC  140.8 bhp    5.0  4.78 Lakh
# 6       Manual      First  23.08 kmpl  1461 CC   63.1 bhp    5.0  4.78 Lakh
# 7    Automatic      First  11.36 kmpl  2755 CC  171.5 bhp    8.0    21 Lakh
#
#    Price
# 0   1.75
# 1  12.50
# 4  17.74
# 6   3.50
# 7  17.50

# %%
sns.countplot(data=df, y="Year")
plt.figure(figsize=(16,8))

# %%
df.columns
# Out:
# Index(['Name', 'Year', 'Kilometers_Driven', 'Fuel_Type', 'Transmission',
#        'Owner_Type', 'Mileage', 'Engine', 'Power', 'Seats', 'New_Price',
#        'Price'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6016 entries, 0 to 6018
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               6016 non-null   object
#  1   Year               6016 non-null   int64
#  2   Kilometers_Driven  6016 non-null   int64
#  3   Fuel_Type          6016 non-null   object
#  4   Transmission       6016 non-null   object
#  5   Owner_Type         6016 non-null   object
#  6   Mileage            6014 non-null   object
#  7   Engine             6016 non-null   object
#  8   Power              5980 non-null   object
#  9   Seats              5974 non-null   float64
#  10  New_Price          6016 non-null   object
#  11  Price              6016 non-null   float64
# dtypes: float64(2), int64(2), object(8)
# memory usage: 740.0+ KB

# %%
df["Seats"] = df["Seats"].astype("object")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6016 entries, 0 to 6018
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               6016 non-null   object
#  1   Year               6016 non-null   int64
#  2   Kilometers_Driven  6016 non-null   int64
#  3   Fuel_Type          6016 non-null   object
#  4   Transmission       6016 non-null   object
#  5   Owner_Type         6016 non-null   object
#  6   Mileage            6014 non-null   object
#  7   Engine             6016 non-null   object
#  8   Power              5980 non-null   object
#  9   Seats              5974 non-null   object
#  10  New_Price          6016 non-null   object
#  11  Price              6016 non-null   float64
# dtypes: float64(1), int64(2), object(9)
# memory usage: 740.0+ KB

# %%
# sns.countplot(data=df, y="Location", hue="Owner_Type")sns.countplot(data=df, y="Location", hue="Owner_Type")

# %%
#For Year Vs Fuel Type
sns.countplot(data=df, y="Year", hue="Fuel_Type")
plt.figure(figsize=(10,8))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6016 entries, 0 to 6018
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               6016 non-null   object
#  1   Year               6016 non-null   int64
#  2   Kilometers_Driven  6016 non-null   int64
#  3   Fuel_Type          6016 non-null   object
#  4   Transmission       6016 non-null   object
#  5   Owner_Type         6016 non-null   object
#  6   Mileage            6014 non-null   object
#  7   Engine             6016 non-null   object
#  8   Power              5980 non-null   object
#  9   Seats              5974 non-null   object
#  10  New_Price          6016 non-null   object
#  11  Price              6016 non-null   float64
# dtypes: float64(1), int64(2), object(9)
# memory usage: 740.0+ KB

# %%
sns.scatterplot(data=df, y="Kilometers_Driven", x="Price")
# Out:
# <Axes: xlabel='Price', ylabel='Kilometers_Driven'>

# %%
custom_palette = {
    "Petrol": "#3498db",     
    "Diesel": "#e74c3c",    
    "CNG": "#2ecc71",       
    "LPG": "#f1c40f",        
    "Electric": "#9b59b6"
}

sns.pairplot(data=df, height=1.5, hue="Fuel_Type", palette=custom_palette)
plt.show()

# %%
df["Brand"] = df["Name"].str.split(' ').str[0]
df["Model"] = df["Name"].str.split(' ').str[1] + df["Name"].str.split(' ').str[2]
df.head()
# Out:
#                                 Name  Year  Kilometers_Driven Fuel_Type  \
# 0             Maruti Wagon R LXI CNG  2010              72000       CNG
# 1   Hyundai Creta 1.6 CRDi SX Option  2015              41000    Diesel
# 4    Audi A4 New 2.0 TDI Multitronic  2013              40670    Diesel
# 6             Nissan Micra Diesel XV  2013              86999    Diesel
# 7  Toyota Innova Crysta 2.8 GX AT 8S  2016              36000    Diesel
#
#   Transmission Owner_Type     Mileage   Engine      Power Seats  New_Price  \
# 0       Manual      First  26.6 km/kg   998 CC  58.16 bhp   5.0  4.78 Lakh
# 1       Manual      First  19.67 kmpl  1582 CC  126.2 bhp   5.0  4.78 Lakh
# 4    Automatic     Second   15.2 kmpl  1968 CC  140.8 bhp   5.0  4.78 Lakh
# 6       Manual      First  23.08 kmpl  1461 CC   63.1 bhp   5.0  4.78 Lakh
# 7    Automatic      First  11.36 kmpl  2755 CC  171.5 bhp   8.0    21 Lakh
#
#    Price    Brand         Model
# 0   1.75   Maruti        WagonR
# ...

# %%
sns.scatterplot(data=df, y="Brand", x="Price")
plt.title("Brand VS Price")
# Out:
# Text(0.5, 1.0, 'Brand VS Price')

# %%
from datetime import date

# %%
df["Cars_Age"] = date.today().year-df["Year"]
df.head()
# Out:
#                                 Name  Year  Kilometers_Driven Fuel_Type  \
# 0             Maruti Wagon R LXI CNG  2010              72000       CNG
# 1   Hyundai Creta 1.6 CRDi SX Option  2015              41000    Diesel
# 4    Audi A4 New 2.0 TDI Multitronic  2013              40670    Diesel
# 6             Nissan Micra Diesel XV  2013              86999    Diesel
# 7  Toyota Innova Crysta 2.8 GX AT 8S  2016              36000    Diesel
#
#   Transmission Owner_Type     Mileage   Engine      Power Seats  New_Price  \
# 0       Manual      First  26.6 km/kg   998 CC  58.16 bhp   5.0  4.78 Lakh
# 1       Manual      First  19.67 kmpl  1582 CC  126.2 bhp   5.0  4.78 Lakh
# 4    Automatic     Second   15.2 kmpl  1968 CC  140.8 bhp   5.0  4.78 Lakh
# 6       Manual      First  23.08 kmpl  1461 CC   63.1 bhp   5.0  4.78 Lakh
# 7    Automatic      First  11.36 kmpl  2755 CC  171.5 bhp   8.0    21 Lakh
#
#    Price    Brand         Model  Cars_Age
# ...

# %%
labels = ["Recent", "Old", "Very Old"]
bins = [0,5,10,20]
df["Car_Bin"] = pd.cut(df["Cars_Age"], bins, labels=labels,)
df.head()
# Out:
#                                 Name  Year  Kilometers_Driven Fuel_Type  \
# 0             Maruti Wagon R LXI CNG  2010              72000       CNG
# 1   Hyundai Creta 1.6 CRDi SX Option  2015              41000    Diesel
# 4    Audi A4 New 2.0 TDI Multitronic  2013              40670    Diesel
# 6             Nissan Micra Diesel XV  2013              86999    Diesel
# 7  Toyota Innova Crysta 2.8 GX AT 8S  2016              36000    Diesel
#
#   Transmission Owner_Type     Mileage   Engine      Power Seats  New_Price  \
# 0       Manual      First  26.6 km/kg   998 CC  58.16 bhp   5.0  4.78 Lakh
# 1       Manual      First  19.67 kmpl  1582 CC  126.2 bhp   5.0  4.78 Lakh
# 4    Automatic     Second   15.2 kmpl  1968 CC  140.8 bhp   5.0  4.78 Lakh
# 6       Manual      First  23.08 kmpl  1461 CC   63.1 bhp   5.0  4.78 Lakh
# 7    Automatic      First  11.36 kmpl  2755 CC  171.5 bhp   8.0    21 Lakh
#
#    Price    Brand         Model  Cars_Age   Car_Bin
# ...

# %%
recent_cars = df[df["Car_Bin"] == "Recent"]
print(recent_cars)
# Out:
# Empty DataFrame
# Columns: [Name, Year, Kilometers_Driven, Fuel_Type, Transmission, Owner_Type, Mileage, Engine, Power, Seats, New_Price, Price, Brand, Model, Cars_Age, Car_Bin]
# Index: []

# %%
sns.set(style="whitegrid")

plt.figure(figsize=(8, 5))
sns.countplot(x="Car_Bin", data=df, order=["Recent", "Old", "Very Old"],
              palette={"Recent": "green", "Old": "orange", "Very Old": "red"})

plt.title("Number of Cars by Age Category", fontsize=14)
plt.xlabel("Car Age Category", fontsize=12)
plt.ylabel("Number of Cars", fontsize=12)
plt.figure(figsize=(10,6))

plt.tight_layout()
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_6072\3361510233.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="Car_Bin", data=df, order=["Recent", "Old", "Very Old"],
